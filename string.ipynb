# %%
#global variable
#global a

#global a
x = 5000
def main():
    x = 1000
    global a
    a = 6000
    print("value of inside the function:", x)
    main()
    print("value of inside the function:", x)
    print("outside the function:", a)

# %% [markdown]
# # string methods

# %%
text = "this is acharya "
print("original text", text)
# Out:
# original text this is acharya

# %%
#slicing
print(text)
# start:stop:step
print(text[0:5])
# Out:
# this is acharya
# this

# %%
print(len(text))
# Out:
# 16

# %%
print(text)
print(text.startswith('this'))
print(text.endswith("rya "))
print(text.upper())
print(text.lower())
print(text.capitalize())
print(text.title())
# Out:
# this is acharya
# True
# True
# THIS IS ACHARYA
# this is acharya
# This is acharya
# This Is Acharya

# %%
# split()
text1 = "hello this is acharya college"
words = text1.split()
print(words)
# Out:
# ['hello', 'this', 'is', 'acharya', 'college']

# %%
#join
word = ['hello', 'this', 'is', 'acharya', 'college']
print(" ".join(word))
# Out:
# hello this is acharya college
