# %%
#to store seven fruits in a list
fruits=[]
for i in range(7):
    fruit=input("enter the fruit name:")
    fruits.append(fruit)
    print("fruits are",fruits)
# Out:
# fruits are ['man']
# fruits are ['man', 'apple']
# fruits are ['man', 'apple', 'kiwi']
# fruits are ['man', 'apple', 'kiwi', 'orange']
# fruits are ['man', 'apple', 'kiwi', 'orange', 'watermelon']
# fruits are ['man', 'apple', 'kiwi', 'orange', 'watermelon', 'pineapple']
# fruits are ['man', 'apple', 'kiwi', 'orange', 'watermelon', 'pineapple', 'straberry']

# %%
#to accept marks of six students
marks=[]
for i in range(6):
    mark=input("enter the marks name{}:")
    marks.append(mark)
    marks.sort()
    print("student marks",marks)
# Out:
# student marks ['34']
# student marks ['34', '67']
# student marks ['34', '67', '99']
# student marks ['34', '65', '67', '99']
# student marks ['34', '45', '65', '67', '99']
# student marks ['34', '45', '65', '67', '69', '99']
