# %%
list1 =[]
print(type(list1))
lisint = [1,2,3,4,5]
print(lisint)
my_list = [1,"hello",90.08]
print(my_list)
#nested list
n_list = ["happy",[2,3,4]]
print(n_list)
# Out:
# <class 'list'>
# [1, 2, 3, 4, 5]
# [1, 'hello', 90.08]
# ['happy', [2, 3, 4]]

# %%
shoplist = ['apple','mango','carrot','banan']
print("i have",len(shoplist),"items to purchase")
print("these are",shoplist)
# Out:
# i have 4 items to purchase
# these are ['apple', 'mango', 'carrot', 'banan']

# %%
#append is used to add one
shoplist.append('rice')
print("my shop list now",shoplist)
# Out:
# my shop list now ['apple', 'mango', 'carrot', 'banan', 'rice']

# %%
#extend is used to add many
shoplist.extend(['kiwi','frui'])
print(shoplist)
# Out:
# ['apple', 'mango', 'carrot', 'banan', 'rice', 'kiwi', 'frui']
